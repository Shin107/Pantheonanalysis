# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from astropy.coordinates import SkyCoord
import astropy.coordinates as coord
import astropy.units as u

# %% [markdown]
# ###### Here I have used the condition angular differnce < 0.1 $^{\circ}$ and difference in MJD's =5.1 days (the 0.1  is just to incluse one more sne)
# The program pancheck.py creates the numpy arrays to check for duplicate sne in different surverys and same surverys note that in the Pantheon+ paper it is stated that only those sne in differnt surveys are considered duplicate

# %%
n1=np.load('Different_surveys/counts.npy')
n2=np.load('Different_surveys/counts2.npy').astype(int)
PAN=pd.read_csv('Pantheon+SH0ES.dat',delimiter=' ')
f=np.load('Different_surveys/final.npy')
n3=np.load('Same_survey/countssib.npy')
n4=np.load('Same_survey/counts2sib.npy').astype(int)
f1=np.load('Same_survey/finalsib.npy')

# %%
pd.set_option('max_rows',None)

# %% [markdown]
# ### Duplicate sne in different surveys

# %%
k,ix,c=np.unique(n1,return_counts=True,return_index=True)
print("there are ",len(k[c==2]),"triple counted SNe")
#PAN.iloc[n1[np.where(c==2)]]

#PAN.iloc[n1[ix]]
#k[c==2]
# Out:
# there are  27 triple counted SNe

# %%
print('Triple counted sne are')
PAN.iloc[k[c==2]]
# Out:
# Triple counted sne are
#          CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  zHELERR  \
# 38    2018gv        18  0.00602  0.00085  0.00596  0.00015  0.00510  0.00015
# 47    2007le        57  0.00630  0.00084  0.00552  0.00001  0.00672  0.00001
# 58   2017erp        51  0.00677  0.00085  0.00727  0.00015  0.00662  0.00015
# 62    2005cf        57  0.00710  0.00084  0.00703  0.00006  0.00644  0.00006
# 67    2003du        57  0.00747  0.00084  0.00664  0.00002  0.00638  0.00002
# 76    2009ig        56  0.00815  0.00084  0.00801  0.00002  0.00877  0.00002
# 88    2005am        57  0.00863  0.00085  0.00841  0.00010  0.00733  0.00010
# 95     2006D        57  0.00925  0.00084  0.00966  0.00005  0.00853  0.00005
# 108    2009Y        56  0.00996  0.00086  0.01050  0.00015  0.00974  0.00015
# 149   2007hj        57  0.01325  0.00085  0.01288  0.00013  0.01411  0.00013
# 152   2008hv        56  0.01375  0.00085  0.01360  0.00007  0.01255  0.00007
# ...

# %%
PAN[PAN['CID']=='2006ej']
# Out:
#         CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  zHELERR  \
# 269  2006ej        57  0.02023  0.00085  0.01926  0.00001  0.02038  0.00001
# 270  2006ej        56  0.02023  0.00085  0.01926  0.00001  0.02038  0.00001
# 271  2006ej         5  0.02023  0.00085  0.01926  0.00001  0.02038  0.00001
# 272  2006ej        64  0.02023  0.00085  0.01926  0.00001  0.02038  0.00001
#
#      m_b_corr  m_b_corr_err_DIAG  ...  PKMJDERR  NDOF   FITCHI2   FITPROB  \
# 269   15.3465           0.186364  ...    0.1327    27  24.73290  0.589430
# 270   15.2482           0.294330  ...    0.3211    22   9.45751  0.990590
# 271   15.3230           0.187974  ...    0.2086    30  16.25700  0.980460
# 272   15.3952           0.185881  ...    0.3289    26  70.67840  0.000005
#
#      m_b_corr_err_RAW  m_b_corr_err_VPEC  biasCor_m_b  biasCorErr_m_b  \
# 269            0.0668             0.0922      -0.0121           0.001
# 270            0.1376             0.0922      -0.0687           0.001
# ...

# %%
print("there are ",len(k[c==3]),'Sne counted four times')
print("which are")
PAN.iloc[k[c==3]]
# Out:
# there are  2 Sne counted four times
# which are
#         CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  zHELERR  \
# 43   2007af        57  0.00625  0.00084  0.00635  0.00001  0.00552  0.00001
# 269  2006ej        57  0.02023  0.00085  0.01926  0.00001  0.02038  0.00001
#
#      m_b_corr  m_b_corr_err_DIAG  ...  PKMJDERR  NDOF   FITCHI2   FITPROB  \
# 43    12.8137           0.324810  ...    0.0490    47  102.9560  0.000005
# 269   15.3465           0.186364  ...    0.1327    27   24.7329  0.589430
#
#      m_b_corr_err_RAW  m_b_corr_err_VPEC  biasCor_m_b  biasCorErr_m_b  \
# 43             0.0576             0.2928      -0.0342           0.002
# 269            0.0668             0.0922      -0.0121           0.001
#
#      biasCor_m_b_COVSCALE  biasCor_m_b_COVADD
# 43                    1.0               0.004
# 269                   1.0               0.004
#
# [2 rows x 47 columns]

# %%
print("there are",len(k[c==1]),'double counted sne')
print("which are")
PAN.iloc[k[c==1]]
# Out:
# there are 107 double counted sne
# which are
#             CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  \
# 0        2011fe        51  0.00122  0.00084  0.00122  0.00002  0.00082
# 2        2012cg        51  0.00256  0.00084  0.00256  0.00002  0.00144
# 6        2013aa        56  0.00331  0.00085  0.00478  0.00015  0.00411
# 8       2017cbv         5  0.00331  0.00085  0.00478  0.00015  0.00411
# 17       2013dy        51  0.00432  0.00084  0.00293  0.00012  0.00394
# 19       2012ht        56  0.00465  0.00084  0.00465  0.00002  0.00352
# 22       2012fr        56  0.00483  0.00085  0.00460  0.00015  0.00492
# 23       2007on         5  0.00483  0.00085  0.00460  0.00015  0.00491
# 27        2015F        56  0.00488  0.00084  0.00515  0.00002  0.00476
# 31      2016coj        51  0.00570  0.00084  0.00489  0.00006  0.00452
# 33       2007sr        57  0.00571  0.00084  0.00660  0.00002  0.00542
# 52       2019np        18  0.00648  0.00084  0.00550  0.00000  0.00452
# ...

# %%
j=np.linspace(0,1700,1701).astype(int)

# %%
#this is the unique list
#PANunique=PAN.iloc[j[~np.in1d(j,n2)]]

# %%
k={1:'SDSS', 4:'SNLS', 5:'CSP', 10:'DES', 15:'PS1MD', 18: 'CNIa0.02', 50:'LOWZ/JRK07', 51:'LOSS1', 56:'SOUSA', 57: 'LOSS2 ', 61:'CFA1', 62:'CFA2', 63:'CFA3S', 64:'CFA3K' ,65:'CFA4p2', 66:'CFA4p3', 100:'HST', 101:'SNAP', 106:'CANDELS', 150:'FOUND'}
print("TABLE of original sne and its duplicate along with the survey \n \n")
print('OriginalSNe  SURVEY     Duplicate SNE   SURVEY ')
print('----------------------------------------------')
for i in f:
    print(PAN.iloc[i[0]]['CID'],'  |  ',k[PAN.iloc[i[0]]['IDSURVEY']],'|\t',PAN.iloc[i[1]]['CID'],'  |  ',k[PAN.iloc[i[1]]['IDSURVEY']])
# Out:
# TABLE of original sne and its duplicate along with the survey
#
#
# OriginalSNe  SURVEY     Duplicate SNE   SURVEY
# ----------------------------------------------
# 2011fe   |   LOSS1 |	 2011fe   |   SOUSA
# 2012cg   |   LOSS1 |	 2012cg   |   SOUSA
# 2013aa   |   SOUSA |	 2013aa   |   CSP
# 2017cbv   |   CSP |	 2017cbv   |   CNIa0.02
# 2013dy   |   LOSS1 |	 2013dy   |   SOUSA
# 2012ht   |   SOUSA |	 2012ht   |   CSP
# 2012fr   |   SOUSA |	 2012fr   |   CSP
# 2007on   |   CSP |	 2007on   |   SOUSA
# 2015F   |   SOUSA |	 2015F   |   CSP
# 2016coj   |   LOSS1 |	 SN2016coj   |   FOUND
# 2007sr   |   LOSS2  |	 2007sr   |   CFA3K
# 2018gv   |   CNIa0.02 |	 2018gv   |   LOSS1
# 2018gv   |   CNIa0.02 |	 2018gv   |   FOUND
# 2007af   |   LOSS2  |	 2007af   |   SOUSA
# 2007af   |   LOSS2  |	 2007af   |   CSP
# 2007af   |   LOSS2  |	 2007af   |   CFA3K
# 2007le   |   LOSS2  |	 2007le   |   CSP
# 2007le   |   LOSS2  |	 2007le   |   CFA4p2
# 2019np   |   CNIa0.02 |	 2019np   |   FOUND
# ...

# %% [markdown]
# ### Duplicate sne in same surveys

# %%
k1,ix1,c1=np.unique(n3,return_counts=True,return_index=True)
print("there are ",len(k1[c1==1]),"double counted SNe")
print("there are ",len(k1[c1==2]),"triple counted SNe")
print("there are ",len(k1[c1==3]),'Sne counted four times')
# Out:
# there are  4 double counted SNe
# there are  0 triple counted SNe
# there are  0 Sne counted four times

# %%
print("TABLE of original sne and its duplicate along with the survey \n \n")
print('OriginalSNe  SURVEY     Duplicate SNE   SURVEY ')
print('----------------------------------------------')
for i in f1:
    print(PAN.iloc[i[0]]['CID'],'  |  ',k[PAN.iloc[i[0]]['IDSURVEY']],'|\t',PAN.iloc[i[1]]['CID'],'  |  ',k[PAN.iloc[i[1]]['IDSURVEY']])
# Out:
# TABLE of original sne and its duplicate along with the survey
#
#
# OriginalSNe  SURVEY     Duplicate SNE   SURVEY
# ----------------------------------------------
# 2005df   |   LOWZ/JRK07 |	 2005df_ANU   |   LOWZ/JRK07
# 1341894   |   DES |	 1345553   |   DES
# 120085   |   PS1MD |	 120094   |   PS1MD
# Ferguson   |   HST |	 Strolger   |   HST

# %%
'''
#rd1=SkyCoord(JLA['ra'], JLA['dec'], unit=u.deg)
rd2=SkyCoord(PAN['RA'], PAN['DEC'], unit=u.deg)
#gal1 = rd1.galactic
gal2 = rd2.galactic
ind1=np.array([])
ind2=np.array([])

#jx=JLA['x1']
px=PAN['x1']

#jz=JLA['zhel']
pz=PAN['zHEL']

#JLAmjd=JLA['tmax']
PANmjd=PAN['PKMJD']
set1=PAN['IDSURVEY']
print('#,PAN[name]1,PAN[name]2,PAN[zcmb]1,PAN[zCMB]2,MJDPAN1,MJDPAN2')
s1=np.array([])
s2=np.array([])
for i in range (len(PAN['RA'])):
    for j in range (i,len(PAN['RA'])):
         if i!=j and j not in ind2:
             if  coord.angular_separation(gal2[i].l,gal2[i].b,gal2[j].l,gal2[j].b)<0.1*u.deg and abs(PANmjd[i]-PANmjd[j])<5.1 and set1[i]!=set1[j]:
                ind1=np.append(ind1,i)
                ind2=np.append(ind2,j)
                print(i,PAN['CID'][i],PAN['CID'][j],PAN['zCMB'][i],PAN['zCMB'][j],PAN['PKMJD'][j],PAN['PKMJD'][j])
'''
# Out:
# "\n#rd1=SkyCoord(JLA['ra'], JLA['dec'], unit=u.deg)\nrd2=SkyCoord(PAN['RA'], PAN['DEC'], unit=u.deg)\n#gal1 = rd1.galactic\ngal2 = rd2.galactic\nind1=np.array([])\nind2=np.array([])\n\n#jx=JLA['x1']\npx=PAN['x1']\n\n#jz=JLA['zhel']\npz=PAN['zHEL']\n\n#JLAmjd=JLA['tmax']\nPANmjd=PAN['PKMJD']\nset1=PAN['IDSURVEY']\nprint('#,PAN[name]1,PAN[name]2,PAN[zcmb]1,PAN[zCMB]2,MJDPAN1,MJDPAN2')\ns1=np.array([])\ns2=np.array([])\nfor i in range (len(PAN['RA'])):\n    for j in range (i,len(PAN['RA'])):\n         if i!=j and j not in ind2:\n             if  coord.angular_separation(gal2[i].l,gal2[i].b,gal2[j].l,gal2[j].b)<0.1*u.deg and abs(PANmjd[i]-PANmjd[j])<5.1 and set1[i]!=set1[j]:\n                ind1=np.append(ind1,i)\n                ind2=np.append(ind2,j)\n                print(i,PAN['CID'][i],PAN['CID'][j],PAN['zCMB'][i],PAN['zCMB'][j],PAN['PKMJD'][j],PAN['PKMJD'][j])\n"
