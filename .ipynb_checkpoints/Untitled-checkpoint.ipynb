# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('counts_Pantheon.o153349',header=2)
n1=np.load('counts.npy')
n2=np.load('counts2.npy').astype(int)
PAN=pd.read_csv('../Pantheo vs JLA/Pantheon+SH0ES.dat',delimiter=' ')

# %%
pd.set_option('max_rows',None)

# %%
PAN.iloc[n1]
# Out:
#             CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  \
# 0        2011fe        51  0.00122  0.00084  0.00122  0.00002  0.00082
# 2        2012cg        51  0.00256  0.00084  0.00256  0.00002  0.00144
# 8       2017cbv         5  0.00331  0.00085  0.00478  0.00015  0.00411
# 17       2013dy        51  0.00432  0.00084  0.00293  0.00012  0.00394
# 19       2012ht        56  0.00465  0.00084  0.00465  0.00002  0.00352
# 22       2012fr        56  0.00483  0.00085  0.00460  0.00015  0.00492
# 23       2007on         5  0.00483  0.00085  0.00460  0.00015  0.00491
# 27        2015F        56  0.00488  0.00084  0.00515  0.00002  0.00476
# 31      2016coj        51  0.00570  0.00084  0.00489  0.00006  0.00452
# 33       2007sr        57  0.00571  0.00084  0.00660  0.00002  0.00542
# 38       2018gv        18  0.00602  0.00085  0.00596  0.00015  0.00510
# 38       2018gv        18  0.00602  0.00085  0.00596  0.00015  0.00510
# ...

# %%
PAN.iloc[n2]
# Out:
#              CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  \
# 1         2011fe        56  0.00122  0.00084  0.00122  0.00002  0.00082
# 3         2012cg        56  0.00256  0.00084  0.00256  0.00002  0.00144
# 9        2017cbv        18  0.00331  0.00085  0.00478  0.00015  0.00411
# 18        2013dy        56  0.00432  0.00084  0.00293  0.00012  0.00394
# 20        2012ht         5  0.00465  0.00084  0.00465  0.00002  0.00352
# 24        2012fr         5  0.00483  0.00085  0.00460  0.00015  0.00492
# 26        2007on        56  0.00483  0.00085  0.00460  0.00015  0.00491
# 28         2015F         5  0.00488  0.00084  0.00515  0.00002  0.00476
# 32     SN2016coj       150  0.00570  0.00084  0.00489  0.00006  0.00452
# 34        2007sr        64  0.00571  0.00084  0.00660  0.00002  0.00542
# 39        2018gv        51  0.00602  0.00085  0.00596  0.00015  0.00510
# 40        2018gv       150  0.00602  0.00085  0.00596  0.00015  0.00510
# ...

# %%
len(n1)

k,c=np.unique(n1,return_counts=True)
print("there are ",len(k[c==2]),"triple counted SNe")
# Out:
# there are  26 triple counted SNe

# %%
print("there are ",len(k[c==3]),'Sne counted four times')
# Out:
# there are  2 Sne counted four times

# %%
print("there are",len(k[c==1]),'double counted sne')
# Out:
# there are 105 double counted sne
